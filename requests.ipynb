# %%
# Install dependencies

# %pip install anthropic python-dotenv dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /home/razvan/.local/lib/python3.10/site-packages (0.121.0)
# Requirement already satisfied: python-dotenv in /home/razvan/.local/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: dotenv in /home/razvan/.local/lib/python3.10/site-packages (0.9.9)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (4.14.2)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic) (1.7.0)
# Requirement already satisfied: sniffio<2,>=1 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/razvan/.local/lib/python3.10/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/razvan/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/razvan/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/razvan/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/razvan/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/razvan/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/razvan/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load Anthrophic API Key

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client

from anthropic import Anthropic

client = Anthropic()

model = "claude-sonnet-5"
max_tokens=1000
user_text = [{"role": "user", "content": "Hello Claude"}]

message = client.messages.create(
    model = model,
    max_tokens = max_tokens,
    messages = user_text,
)

# %%
print(message.content[0].text)
# Out:
# Hi there! How's it going? Is there something I can help you with today, or just saying hello?
