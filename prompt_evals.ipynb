# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
    Please solve the following task:

    {test_case["task"]}
"""
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run prompt, the grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Region Extractor\n\nHere's a Python function that extracts the AWS region from an S3 bucket URL:\n\n```python\nimport re\nfrom urllib.parse import urlparse\n\ndef extract_region_from_s3_url(s3_url: str) -> str:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URL.\n    \n    Supports formats:\n    - s3://bucket-name.region.amazonaws.com\n    - https://bucket-name.s3.region.amazonaws.com\n    - https://s3.region.amazonaws.com/bucket-name\n    - s3://bucket-name (returns None or default)\n    \n    Args:\n        s3_url: S3 bucket URL string\n        \n    Returns:\n        str: AWS region name, or None if region cannot be determined\n        \n    Raises:\n        ValueError: If URL is invalid\n    \"\"\"\n    if not s3_url:\n        raise ValueError(\"URL cannot be empty\")\n    \n    # Pattern 1: s3://bucket-name.region.amazonaws.com\n    pattern1 = r's3://[^.]+\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern1, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 2: https://bucket-name.s3.region.amazonaws.com\n    pattern2 = r'https?://[^.]+\\.s3\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern2, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 3: https://s3.region.amazonaws.com/bucket-name\n    pattern3 = r'https?://s3\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    match = re.search(pattern3, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 4: https://bucket-name.s3.amazonaws.com (us-east-1 default)\n    pattern4 = r'https?://[^.]+\\.s3\\.amazonaws\\.com'\n    match = re.search(pattern4, s3_url)\n    if match:\n        return 'us-east-1'  # Default region\n    \n    raise ValueError(f\"Could not extract region from URL: {s3_url}\")\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_urls = [\n        \"s3://my-bucket.us-west-2.amazonaws.com\",\n        \"https://my-bucket.s3.eu-west-1.amazonaws.com\",\n        \"https://s3.ap-southeast-1.amazonaws.com/my-bucket\",\n        \"https://my-bucket.s3.amazonaws.com\",\n        \"s3://data-bucket.ca-central-1.amazonaws.com\",\n    ]\n    \n    for url in test_urls:\n        try:\n            region = extract_region_from_s3_url(url)\n            print(f\"\u2713 {url} \u2192 {region}\")\n        except ValueError as e:\n            print(f\"\u2717 {url} \u2192 Error: {e}\")\n```\n\n**Output:**\n```\n\u2713 s3://my-bucket.us-west-2.amazonaws.com \u2192 us-west-2\n\u2713 https://my-bucket.s3.eu-west-1.amazonaws.com \u2192 eu-west-1\n\u2713 https://s3.ap-southeast-1.amazonaws.com/my-bucket \u2192 ap-southeast-1\n\u2713 https://my-bucket.s3.amazonaws.com \u2192 us-east-1\n\u2713 s3://data-bucket.ca-central-1.amazonaws.com \u2192 ca-central-1\n```\n\n## Simpler Version (if only one format needed):\n\n```python\nimport re\n\ndef extract_region_from_s3_url(s3_url: str) -> str:\n    \"\"\"Extract region from s3://bucket-name.region.amazonaws.com format\"\"\"\n    match",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL in the format 's3://bucket-name.region.amazonaws.com'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an IAM policy for read-only access to all objects in an S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Specifies the policy language version (use `2012-10-17`) |\n| **Statement 1** | Allows reading objects from the bucket |\n| **Statement 2** | Allows listing bucket contents and checking bucket location |\n| **Resource ARNs** | `/*` = objects; without `/*` = bucket itself |\n\n## Permissions Granted\n- \u2705 `s3:GetObject` - Download/read objects\n- \u2705 `s3:GetObjectVersion` - Read object versions\n- \u2705 `s3:ListBucket` - List bucket contents\n- \u2705 `s3:GetBucketLocation` - View bucket region\n\n## Permissions Denied\n- \u274c Upload/delete objects\n- \u274c Modify bucket settings\n- \u274c Change permissions\n\nThis policy follows AWS best practices by using separate statements for object and bucket-level permissions.",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows read-only access to all objects in an S3 bucket named 'my-data-bucket'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string |\n| `i-` | Literal \"i-\" prefix (required for all EC2 instance IDs) |\n| `[0-9a-f]` | Matches any single hexadecimal character (0-9, a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string |\n\n## Examples\n\n### Valid matches:\n```\ni-0a1b2c3d4e5f6g7h8\ni-1234567890abcdef0\ni-ffffffffffffffff\n```\n\n### Invalid matches:\n```\ni-0a1b2c3d4e5f6g7    (too short - only 16 chars)\ni-0a1b2c3d4e5f6g7h8i (too long - 18 chars)\nec2-1234567890abcdef (wrong prefix)\ni_0a1b2c3d4e5f6g7h8  (underscore instead of hyphen)\n```\n\n## Implementation Examples\n\n### JavaScript\n```javascript\nconst regex = /^i-[0-9a-f]{17}$/;\nconsole.log(regex.test('i-0a1b2c3d4e5f6g7h8')); // true\n```\n\n### Python\n```python\nimport re\nregex = r'^i-[0-9a-f]{17}$'\nre.match(regex, 'i-0a1b2c3d4e5f6g7h8')  # Match object (valid)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters)"
#     },
#     "score": 10
#   }
# ]
